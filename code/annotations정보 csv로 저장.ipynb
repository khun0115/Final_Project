# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm
font_name = fm.FontProperties(fname="C:\Windows\Fonts\\malgun.ttf").get_name()
plt.rc("font", family=font_name)
import matplotlib as mlp
mlp.rcParams["axes.unicode_minus"] = False

# %%
from datetime import datetime
import cv2
import zipfile
import shutil
import os
import glob
import json
from tqdm.notebook import tqdm

# %% [markdown]
# # 1. labeling_json 가져와서 csv파일로 저장

# %% [markdown]
# ## 1) damage

# %%
train_label_list = glob.glob("C:\\eun01\\car_repair\\training\\labeling_data\\damage\\*")

# %%
print(len(train_label_list))
# Out:
# 403559

# %%
print(train_label_list[1])
# Out:
# C:\eun01\car_repair\training\labeling_data\damage\0000003_as-0036229.json

# %%
train_label_list[10000].split("\\")[-1][:7]
# Out:
# '0012517'

# %%
image_id=[]
category_id=[]
segmentation=[]
area=[]
bbox=[]
damage=[]
year=[]
color=[]
repair=[]
supercategory_name=[]

num=0  # 000001 과 같이 폴더명에 있는 이미지 파일 이름 가져오기
for file_name in tqdm(train_label_list):
    with open(file_name,'r') as j:
        contents=json.loads(j.read())

    for i in range(len(contents["annotations"])):
        image_id.append(train_label_list[num].split("\\")[-1][:7])
        category_id.append(contents["annotations"][i]["category_id"])
        segmentation.append(contents["annotations"][i]["segmentation"])
        area.append(contents["annotations"][i]["area"])
        bbox.append(contents["annotations"][i]["bbox"])
        damage.append(contents["annotations"][i]["damage"])
        year.append(contents["annotations"][i]["year"])
        color.append(contents["annotations"][i]["color"])
        repair.append(contents["annotations"][i]["repair"])
        supercategory_name.append(contents["categories"]["supercategory_name"])
    num+=1
        
car_repair1=pd.DataFrame({"image_id":image_id, "category_id":category_id, "segmentation":segmentation,
                         "area":area, "bbox":bbox, "damage":damage, "year":year, "color":color, "repair":repair,
                         "supercategory_name":supercategory_name})
# Out:
#   0%|          | 0/403559 [00:00<?, ?it/s]

# %%
car_repair1["image_id"] = car_repair1['image_id'].astype(str)
car_repair1.dtypes
# Out:
# image_id               object
# category_id            object
# segmentation           object
# area                  float64
# bbox                   object
# damage                 object
# year                    int64
# color                  object
# repair                 object
# supercategory_name     object
# dtype: object

# %%
car_repair1.tail()
# Out:
#         image_id category_id  \
# 1237498  0506231   sc-202337
# 1237499  0506231   sc-202337
# 1237500  0506232   sc-202337
# 1237501  0506232   sc-202337
# 1237502  0506232   sc-202337
#
#                                               segmentation     area  \
# 1237498  [[[[341, 487], [312, 397], [271, 338], [298, 3...   9806.5
# 1237499  [[[[401, 451], [407, 427], [415, 391], [408, 4...    142.0
# 1237500  [[[[646, 358], [661, 337], [713, 294], [736, 3...  20154.0
# 1237501  [[[[186, 271], [246, 235], [362, 207], [452, 2...   2812.0
# 1237502  [[[[592, 355], [705, 307], [799, 223], [800, 2...   3578.0
#
#                          bbox     damage  year  color  \
# 1237498  [271, 317, 122, 175]  Scratched  2017  White
# 1237499    [401, 391, 14, 60]  Separated  2017  White
# 1237500  [646, 294, 154, 213]  Scratched  2017  White
# 1237501   [186, 207, 268, 73]  Scratched  2017  White
# 1237502  [592, 223, 208, 154]  Separated  2017  White
#
#                                               repair supercategory_name
# 1237498  [Front bumper:coating,exchange,sheet_metal]            CityCar
# 1237499  [Front bumper:coating,exchange,sheet_metal]            CityCar
# 1237500  [Front bumper:coating,exchange,sheet_metal]            CityCar
# 1237501  [Front bumper:coating,exchange,sheet_metal]            CityCar
# 1237502  [Front bumper:coating,exchange,sheet_metal]            CityCar

# %% [markdown]
# ### save

# %%
v1 = car_repair1[:600000]
v1.to_csv("car_repair1.csv", index=False)

# %%
v2 = car_repair1[600000:]
v2.to_csv("car_repair2.csv", index=False)

# %%
car_repair = pd.read_csv("car_repair1.csv")
car_repair.head()
# Out:
#    image_id category_id                                       segmentation  \
# 0         2  as-0036229  [[[[438, 504], [440, 443], [436, 419], [439, 4...
# 1         3  as-0036229  [[[[469, 497], [448, 479], [458, 437], [461, 4...
# 2         4  as-0036229  [[[[73, 596], [69, 588], [67, 582], [65, 575],...
# 3         4  as-0036229  [[[[107, 371], [108, 362], [445, 361], [795, 3...
# 4         5  as-0036229  [[[[77, 390], [87, 375], [452, 351], [560, 356...
#
#       area                  bbox     damage  year  color  \
# 0  14977.0  [336, 159, 198, 345]   Breakage  2020  Black
# 1   7186.5  [378, 209, 154, 288]   Breakage  2020  Black
# 2    749.5     [53, 543, 31, 53]   Breakage  2020  Black
# 3  13872.5   [107, 356, 688, 29]  Scratched  2020  Black
# 4  22816.0    [77, 351, 690, 52]  Scratched  2020  Black
#
#                              repair supercategory_name
# 0  ['Rear bumper:coating,exchange']      Full-size car
# 1  ['Rear bumper:coating,exchange']      Full-size car
# 2  ['Rear bumper:coating,exchange']      Full-size car
# 3  ['Rear bumper:coating,exchange']      Full-size car
# 4  ['Rear bumper:coating,exchange']      Full-size car

# %%
car_repair1 = pd.read_csv("car_repair2.csv")
car_repair1.head()
# Out:
#    image_id category_id                                       segmentation  \
# 0    246195  as-0073313  [[[[496, 316], [508, 320], [510, 334], [480, 4...
# 1    246195  as-0073313  [[[[534, 386], [530, 408], [514, 403], [517, 3...
# 2    246195  as-0073313  [[[[233, 261], [226, 269], [254, 277], [270, 2...
# 3    246195  as-0073313  [[[[330, 283], [328, 331], [337, 326], [339, 2...
# 4    246195  as-0073313  [[[[488, 222], [482, 234], [477, 275], [491, 2...
#
#      area                bbox     damage  year      color  \
# 0  1207.5  [473, 316, 37, 91]  Scratched  2017  Gray tone
# 1   281.0  [514, 383, 20, 25]  Scratched  2017  Gray tone
# 2   628.0  [226, 258, 55, 19]  Scratched  2017  Gray tone
# 3   401.0  [328, 283, 11, 48]   Breakage  2017  Gray tone
# 4   893.0  [477, 222, 28, 54]   Breakage  2017  Gray tone
#
#                              repair supercategory_name
# 0  ['Rear bumper:coating,exchange']       Mid-size car
# 1  ['Rear bumper:coating,exchange']       Mid-size car
# 2  ['Rear bumper:coating,exchange']       Mid-size car
# 3  ['Rear bumper:coating,exchange']       Mid-size car
# 4  ['Rear bumper:coating,exchange']       Mid-size car

# %% [markdown]
# ## 2) damage_part

# %%
train_label_list2 = glob.glob("C:\\eun01\\car_repair\\training\\labeling_data\\damage_part\\*")

# %%
print(len(train_label_list2))
# Out:
# 109062

# %%
image_id=[]
category_id=[]
segmentation=[]
area=[]
bbox=[]
damage=[]
year=[]
color=[]
repair=[]
supercategory_name=[]

num=0
for file_name in tqdm(train_label_list2):
    with open(file_name,'r') as j:
        contents2=json.loads(j.read())

    for i in range(len(contents2["annotations"])):
        image_id.append(train_label_list2[num].split("\\")[-1][:7])
        category_id.append(contents2["annotations"][i]["category_id"])
        segmentation.append(contents2["annotations"][i]["segmentation"])
        area.append(contents2["annotations"][i]["area"])
        bbox.append(contents2["annotations"][i]["bbox"])
        damage.append(contents2["annotations"][i]["damage"])
        year.append(contents2["annotations"][i]["year"])
        color.append(contents2["annotations"][i]["color"])
        repair.append(contents2["annotations"][i]["repair"])
        supercategory_name.append(contents2["categories"]["supercategory_name"])
    num+=1
        
car_repair2=pd.DataFrame({"image_id":image_id, "category_id":category_id, "segmentation":segmentation,
                          "area":area, "bbox":bbox, "damage":damage, "year":year, "color":color, "repair":repair,
                          "supercategory_name":supercategory_name})
# Out:
#   0%|          | 0/109062 [00:00<?, ?it/s]

# %%
car_repair2["image_id"] = car_repair2['image_id'].astype(str)
car_repair2["image_id"].dtypes

# %%
car_repair2.head()
# Out:
#   image_id category_id                                       segmentation  \
# 0  0000001  as-2866890  [[[[234, 441], [231, 419], [255, 401], [281, 3...
# 1  0000001  as-2866890  [[[[523, 33], [562, 28], [601, 71], [604, 91],...
# 2  0000008  as-0036229  [[[[206, 530], [222, 520], [256, 521], [273, 5...
# 3  0000008  as-0036229  [[[[204, 517], [197, 533], [195, 521], [194, 5...
# 4  0000008  as-0036229  [[[[59, 356], [85, 367], [118, 372], [130, 418...
#
#        area                 bbox     damage  year   color  \
# 0     865.5   [231, 389, 56, 52]  Scratched  2019  Others
# 1  102580.0    [9, 28, 598, 425]       None  2019  Others
# 2    3154.5    [89, 505, 43, 19]  Separated  2020   Black
# 3     282.0   [177, 503, 27, 30]  Separated  2020   Black
# 4   78361.5  [59, 356, 665, 217]       None  2020   Black
#
#                            repair supercategory_name
# 0   [Front fender(L):sheet_metal]      Full-size car
# 1     Front fender(L):sheet_metal      Full-size car
# 2  [Rear bumper:coating,exchange]      Full-size car
# 3  [Rear bumper:coating,exchange]      Full-size car
# 4    Rear bumper:coating,exchange      Full-size car

# %% [markdown]
# ### save

# %%
car_repair2.to_csv("car_repair3.csv", index=False)

# %%
car_repair2 = pd.read_csv("car_repair3.csv")
car_repair2.head()
# Out:
#    image_id category_id                                       segmentation  \
# 0         1  as-2866890  [[[[234, 441], [231, 419], [255, 401], [281, 3...
# 1         1  as-2866890  [[[[523, 33], [562, 28], [601, 71], [604, 91],...
# 2         8  as-0036229  [[[[206, 530], [222, 520], [256, 521], [273, 5...
# 3         8  as-0036229  [[[[204, 517], [197, 533], [195, 521], [194, 5...
# 4         8  as-0036229  [[[[59, 356], [85, 367], [118, 372], [130, 418...
#
#        area                 bbox     damage  year   color  \
# 0     865.5   [231, 389, 56, 52]  Scratched  2019  Others
# 1  102580.0    [9, 28, 598, 425]        NaN  2019  Others
# 2    3154.5    [89, 505, 43, 19]  Separated  2020   Black
# 3     282.0   [177, 503, 27, 30]  Separated  2020   Black
# 4   78361.5  [59, 356, 665, 217]        NaN  2020   Black
#
#                              repair supercategory_name
# 0   ['Front fender(L):sheet_metal']      Full-size car
# 1       Front fender(L):sheet_metal      Full-size car
# 2  ['Rear bumper:coating,exchange']      Full-size car
# 3  ['Rear bumper:coating,exchange']      Full-size car
# 4      Rear bumper:coating,exchange      Full-size car

# %% [markdown]
# # 2. csv 파일 danage별로 저장

# %%
car_repair_all = pd.concat([car_repair, car_repair1, car_repair2], ignore_index=True)

# %%
car_repair_all.head()
# Out:
#    image_id category_id                                       segmentation  \
# 0         2  as-0036229  [[[[438, 504], [440, 443], [436, 419], [439, 4...
# 1         3  as-0036229  [[[[469, 497], [448, 479], [458, 437], [461, 4...
# 2         4  as-0036229  [[[[73, 596], [69, 588], [67, 582], [65, 575],...
# 3         4  as-0036229  [[[[107, 371], [108, 362], [445, 361], [795, 3...
# 4         5  as-0036229  [[[[77, 390], [87, 375], [452, 351], [560, 356...
#
#       area                  bbox     damage  year  color  \
# 0  14977.0  [336, 159, 198, 345]   Breakage  2020  Black
# 1   7186.5  [378, 209, 154, 288]   Breakage  2020  Black
# 2    749.5     [53, 543, 31, 53]   Breakage  2020  Black
# 3  13872.5   [107, 356, 688, 29]  Scratched  2020  Black
# 4  22816.0    [77, 351, 690, 52]  Scratched  2020  Black
#
#                              repair supercategory_name
# 0  ['Rear bumper:coating,exchange']      Full-size car
# 1  ['Rear bumper:coating,exchange']      Full-size car
# 2  ['Rear bumper:coating,exchange']      Full-size car
# 3  ['Rear bumper:coating,exchange']      Full-size car
# 4  ['Rear bumper:coating,exchange']      Full-size car

# %%
car_repair_all = car_repair_all.sort_values("image_id")
car_repair_all.head()
# Out:
#          image_id category_id  \
# 1237503         1  as-2866890
# 1237504         1  as-2866890
# 0               2  as-0036229
# 1               3  as-0036229
# 3               4  as-0036229
#
#                                               segmentation      area  \
# 1237503  [[[[234, 441], [231, 419], [255, 401], [281, 3...     865.5
# 1237504  [[[[523, 33], [562, 28], [601, 71], [604, 91],...  102580.0
# 0        [[[[438, 504], [440, 443], [436, 419], [439, 4...   14977.0
# 1        [[[[469, 497], [448, 479], [458, 437], [461, 4...    7186.5
# 3        [[[[107, 371], [108, 362], [445, 361], [795, 3...   13872.5
#
#                          bbox     damage  year   color  \
# 1237503    [231, 389, 56, 52]  Scratched  2019  Others
# 1237504     [9, 28, 598, 425]        NaN  2019  Others
# 0        [336, 159, 198, 345]   Breakage  2020   Black
# 1        [378, 209, 154, 288]   Breakage  2020   Black
# 3         [107, 356, 688, 29]  Scratched  2020   Black
#
#                                    repair supercategory_name
# 1237503   ['Front fender(L):sheet_metal']      Full-size car
# 1237504       Front fender(L):sheet_metal      Full-size car
# 0        ['Rear bumper:coating,exchange']      Full-size car
# 1        ['Rear bumper:coating,exchange']      Full-size car
# 3        ['Rear bumper:coating,exchange']      Full-size car

# %%
len(car_repair_all)
# Out:
# 1800216

# %%
car_repair_all["damage"].unique()
# Out:
# array(['Scratched', nan, 'Breakage', 'Separated', 'Crushed'], dtype=object)

# %%
Scratched = car_repair_all[car_repair_all["damage"]=="Scratched"]
Breakage = car_repair_all[car_repair_all["damage"]=="Breakage"]
Separated = car_repair_all[car_repair_all["damage"]=="Separated"]
Crushed = car_repair_all[car_repair_all["damage"]=="Crushed"]
Null = car_repair_all[car_repair_all["damage"].isnull()]

# %%
Scratched.to_csv("Scratched.csv", index=False)
Breakage.to_csv("Breakage.csv", index=False)
Separated.to_csv("Separated.csv", index=False)
Crushed.to_csv("Crushed.csv", index=False)
Null.to_csv("Null.cav", index=True)
