# %%
import os
from glob import glob
import json

# %%
import os

os.getcwd()

# %%
import pandas as pd

# %%
from glob import glob

j_list = glob('/Users/kimdohyun/Downloads/final_project/New_Sample/라벨링데이터/TL_damage/damage/*.json')
j_list[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 4
#       1 from glob import glob
#       3 j_list = glob('/Users/kimdohyun/Downloads/final_project/New_Sample/라벨링데이터/TL_damage/damage/*.json')
# ----> 4 j_list[0]
#
# IndexError: list index out of range

# %%
import json

file = open(j_list[0],"r",encoding='utf-8')
jsondata = json.load(file)

print(type(jsondata))
print(jsondata)
# Out:
# <class 'dict'>
# {'info': {'name': 'socar', 'date_created': '03/08/2022'}, 'images': {'id': 1, 'width': 960, 'height': 720, 'file_name': '0063158_sc-155544.jpg'}, 'annotations': [{'id': 2, 'image_id': 1, 'category_id': 'sc-155544', 'segmentation': [[[[543, 312], [715, 282], [773, 291], [713, 329], [549, 340], [543, 312]]]], 'area': 7713.0, 'bbox': [543, 282, 230, 58], 'damage': 'Breakage', 'part': None, 'year': 2018, 'color': 'White', 'level': None, 'repair': []}, {'id': 3, 'image_id': 1, 'category_id': 'sc-155544', 'segmentation': [[[[448, 160], [496, 251], [552, 360], [576, 491], [578, 584], [560, 692], [550, 694], [566, 590], [564, 517], [543, 398], [526, 338], [469, 213], [440, 162], [448, 160]]]], 'area': 6706.5, 'bbox': [440, 160, 138, 534], 'damage': 'Scratched', 'part': None, 'year': 2018, 'color': 'White', 'level': None, 'repair': []}], 'categories': {'id': 'sc-155544', 'supercategory_name': 'Compact car'}}

# %%
print(json.dumps(jsondata,indent='\t'))
# Out:
# {
# 	"info": {
# 		"name": "socar",
# 		"date_created": "03/08/2022"
# 	},
# 	"images": {
# 		"id": 1,
# 		"width": 960,
# 		"height": 720,
# 		"file_name": "0063158_sc-155544.jpg"
# 	},
# 	"annotations": [
# 		{
# 			"id": 2,
# 			"image_id": 1,
# 			"category_id": "sc-155544",
# 			"segmentation": [
# 				[
# 					[
# 						[
# 							543,
# 							312
# 						],
# 						[
# 							715,
# 							282
# 						],
# 						[
# 							773,
# 							291
# 						],
# 						[
# 							713,
# 							329
# 						],
# 						[
# 							549,
# 							340
# 						],
# 						[
# 							543,
# 							312
# 						]
# 					]
# 				]
# 			],
# 			"area": 7713.0,
# 			"bbox": [
# 				543,
# 				282,
# 				230,
# 				58
# 			],
# 			"damage": "Breakage",
# 			"part": null,
# 			"year": 2018,
# 			"color": "White",
# 			"level": null,
# 			"repair": []
# 		},
# 		{
# 			"id": 3,
# 			"image_id": 1,
# 			"category_id": "sc-155544",
# 			"segmentation": [
# 				[
# 					[
# 						[
# 							448,
# ...

# %%
file = open(j_list[1],"r",encoding='utf-8')
jsondata = json.load(file)

# print(type(jsondata))
print(jsondata)

print(json.dumps(jsondata,indent='\t'))
# Out:
# {'info': {'name': 'external', 'date_created': '03/08/2022'}, 'images': {'id': 1, 'width': 800, 'height': 1067, 'file_name': '0349939_as-2753180.jpg'}, 'annotations': [{'id': 2, 'image_id': 1, 'category_id': 'as-2753180', 'segmentation': [[[[0, 476], [490, 414], [409, 431], [0, 495], [0, 476]]]], 'area': 5539.5, 'bbox': [0, 414, 490, 81], 'damage': 'Separated', 'part': None, 'year': 2016, 'color': 'Red tone', 'level': None, 'repair': ['Front bumper:coating,exchange', 'Front Wheel(R):exchange', 'Head lights:exchange', 'Front fender(R):coating,exchange']}, {'id': 3, 'image_id': 1, 'category_id': 'as-2753180', 'segmentation': [[[[0, 492], [306, 443], [535, 410], [586, 447], [639, 466], [733, 466], [793, 477], [799, 476], [797, 667], [742, 649], [641, 663], [487, 701], [428, 722], [299, 683], [247, 630], [147, 684], [69, 745], [3, 810], [0, 492]]]], 'area': 188330.5, 'bbox': [0, 410, 799, 400], 'damage': 'Crushed', 'part': None, 'year': 2016, 'color': 'Red tone', 'level': None, 'repair': 
# ...

# %%
file = open(j_list[2],"r",encoding='utf-8')
jsondata = json.load(file)


print(json.dumps(jsondata,indent='\t'))
# Out:
# {
# 	"info": {
# 		"name": "socar",
# 		"date_created": "03/08/2022"
# 	},
# 	"images": {
# 		"id": 1,
# 		"width": 1280,
# 		"height": 960,
# 		"file_name": "0327762_sc-198391.jpg"
# 	},
# 	"annotations": [
# 		{
# 			"id": 2,
# 			"image_id": 1,
# 			"category_id": "sc-198391",
# 			"segmentation": [
# 				[
# 					[
# 						[
# 							798,
# 							409
# 						],
# 						[
# 							792,
# 							424
# 						],
# 						[
# 							774,
# 							473
# 						],
# 						[
# 							754,
# 							512
# 						],
# 						[
# 							737,
# 							573
# 						],
# 						[
# 							716,
# 							672
# 						],
# 						[
# 							685,
# 							723
# 						],
# 						[
# 							634,
# 							750
# 						],
# 						[
# 							623,
# 							742
# 						],
# 						[
# 							620,
# 							716
# 						],
# 						[
# 							630,
# 							656
# 						],
# 						[
# 							641,
# 							562
# 						],
# 						[
# 							663,
# 							520
# 						],
# 						[
# 							719,
# 							472
# 						],
# ...

# %% [markdown]
# id:1 은 이미지. 2부터 파손 종류의 정보 담은 주석. category 에도 id 1개 있으므로 findall(len(id))-2 하면 파손 종류 개수?
#
# segmentation 좌표로 면적 그려서 파손별 영역 파악?

# %%
import json

file = open(j_list[0],"r",encoding='utf-8')
jsondata = json.load(file)

print(type(jsondata))
print(jsondata)
# Out:
# <class 'dict'>
# {'info': {'name': 'socar', 'date_created': '03/08/2022'}, 'images': {'id': 1, 'width': 800, 'height': 600, 'file_name': '0506233_sc-202337.jpg'}, 'annotations': [{'id': 2, 'image_id': 1, 'category_id': 'sc-202337', 'segmentation': [[[[419, 225], [422, 206], [430, 204], [428, 222], [419, 225]]]], 'area': 151.0, 'bbox': [419, 204, 11, 21], 'damage': 'Breakage', 'part': None, 'year': 2017, 'color': 'White', 'level': None, 'repair': ['Front bumper:coating,exchange,sheet_metal']}, {'id': 3, 'image_id': 1, 'category_id': 'sc-202337', 'segmentation': [[[[2, 21], [481, 186], [478, 197], [800, 20], [800, 43], [719, 103], [554, 186], [372, 253], [354, 243], [468, 206], [328, 158], [2, 41], [2, 21]]]], 'area': 22553.5, 'bbox': [2, 20, 798, 233], 'damage': 'Separated', 'part': None, 'year': 2017, 'color': 'White', 'level': None, 'repair': ['Front bumper:coating,exchange,sheet_metal']}], 'categories': {'id': 'sc-202337', 'supercategory_name': 'CityCar'}}

# %%
print(json.dumps(jsondata,indent='\t'))
# Out:
# {
# 	"info": {
# 		"name": "socar",
# 		"date_created": "03/08/2022"
# 	},
# 	"images": {
# 		"id": 1,
# 		"width": 800,
# 		"height": 600,
# 		"file_name": "0506233_sc-202337.jpg"
# 	},
# 	"annotations": [
# 		{
# 			"id": 2,
# 			"image_id": 1,
# 			"category_id": "sc-202337",
# 			"segmentation": [
# 				[
# 					[
# 						[
# 							419,
# 							225
# 						],
# 						[
# 							422,
# 							206
# 						],
# 						[
# 							430,
# 							204
# 						],
# 						[
# 							428,
# 							222
# 						],
# 						[
# 							419,
# 							225
# 						]
# 					]
# 				]
# 			],
# 			"area": 151.0,
# 			"bbox": [
# 				419,
# 				204,
# 				11,
# 				21
# 			],
# 			"damage": "Breakage",
# 			"part": null,
# 			"year": 2017,
# 			"color": "White",
# 			"level": null,
# 			"repair": [
# 				"Front bumper:coating,exchange,sheet_metal"
# 			]
# 		},
# 		{
# 			"id": 3,
# 			"image_id": 1,
# 			"category_id": "sc-202337",
# 			"segmentation": [
# 				[
# 					[
# 						[
# 							2,
# ...

# %%
import json

add_list = glob('D:\\Down\\car_crushed\\data\\1.Training\\1.원천데이터_230126_add\\TS_99. 붙임_견적서/*.json')

add_list
# Out:
# ['D:\\Down\\car_crushed\\data\\1.Training\\1.원천데이터_230126_add\\TS_99. 붙임_견적서\\as-0000002.json',
#  'D:\\Down\\car_crushed\\data\\1.Training\\1.원천데이터_230126_add\\TS_99. 붙임_견적서\\as-0000004.json',
#  'D:\\Down\\car_crushed\\data\\1.Training\\1.원천데이터_230126_add\\TS_99. 붙임_견적서\\as-0000005.json',
#  'D:\\Down\\car_crushed\\data\\1.Training\\1.원천데이터_230126_add\\TS_99. 붙임_견적서\\as-0000009.json',
#  'D:\\Down\\car_crushed\\data\\1.Training\\1.원천데이터_230126_add\\TS_99. 붙임_견적서\\as-0000011.json',
#  'D:\\Down\\car_crushed\\data\\1.Training\\1.원천데이터_230126_add\\TS_99. 붙임_견적서\\as-0000012.json',
#  'D:\\Down\\car_crushed\\data\\1.Training\\1.원천데이터_230126_add\\TS_99. 붙임_견적서\\as-0000013.json',
#  'D:\\Down\\car_crushed\\data\\1.Training\\1.원천데이터_230126_add\\TS_99. 붙임_견적서\\as-0000018.json',
#  'D:\\Down\\car_crushed\\data\\1.Training\\1.원천데이터_230126_add\\TS_99. 붙임_견적서\\as-0000019.json',
#  'D:\\Down\\car_crushed\\data\\1.Training\\1.원천데이터_230126_add\\TS_99. 붙임_견적서\\as-0000021.json',
# ...

# %%
file = open(add_list[0],"r",encoding='utf-8')
jsondata = json.load(file)

# print(json.dumps(jsondata,indent='\t'))
# Out:
# {
# 	"\ucc28\ub7c9\uc815\ubcf4": {
# 		"\uc81c\uc791\uc0ac/\ucc28\uc885": "FORD",
# 		"\ucc28\ub7c9\uba85\uce6d": "\ud3ec\ub4dc",
# 		"\ubaa8\ub378": "\uae30\ubcf8\ud615",
# 		"\ucd5c\ucd08\ub4f1\ub85d\uc77c": "20150101",
# 		"\ubd80\ud488\uc801\uc6a9\uc77c": "20180507",
# 		"\uc8fc\ud589\uac70\ub9ac": "67,219Km",
# 		"\uc785\uace0\uc77c\uc790": "20180507",
# 		"\ucd9c\uace0\uc77c\uc790": "",
# 		"\ud0c8\ubd80\ucc29\uc791\uc5c5\uc2dc\uac04": "\uae30\uc874",
# 		"\ud0c8\ubd80\ucc29M/H": "33,000\uc6d0",
# 		"\ud310\uae08M/H": "33,000\uc6d0",
# 		"\ub3c4\uc7a5\uc791\uc5c5\uc2dc\uac04": "\uae30\uc874",
# 		"\ub3c4\uc7a5M/H": "\uc6d0",
# 		"\uc911\ubcf5\uccb4\ud06c": "\ubbf8\uc644\ub8cc"
# 	},
# 	"\uc218\ub9ac\ube44 \uc815\uc0b0\uc815\ubcf4": {
# 		"\uacf5\uc784": {
# 			"\ud0c8\ucc29\uad50\ud658": "227,370",
# 			"\ud310\uae08\uc218\ub9ac": "363,000",
# 			"\uacac\uc778\uad6c\ub09c": "0",
# 			"\uc7ac\ub8cc\ub300": "0",
# 			"\ub3c4\uc7a5\uacf5\uc784": "851,000",
# ...

# %%
print(jsondata)
# Out:
# {'차량정보': {'제작사/차종': 'FORD', '차량명칭': '포드', '모델': '기본형', '최초등록일': '20150101', '부품적용일': '20180507', '주행거리': '67,219Km', '입고일자': '20180507', '출고일자': '', '탈부착작업시간': '기존', '탈부착M/H': '33,000원', '판금M/H': '33,000원', '도장작업시간': '기존', '도장M/H': '원', '중복체크': '미완료'}, '수리비 정산정보': {'공임': {'탈착교환': '227,370', '판금수리': '363,000', '견인구난': '0', '재료대': '0', '도장공임': '851,000', '할증공임': '0', '가열건조비': '0', '도장정산': '851,000', '공임소계': '1,441,370'}, '부품': {'순정부품': '0', '순정정산': '0', '방청부품': '', '방청정산': '', '중고부품': '0', '유리부품': '0', '부품소계': '0', '감가상각': '0', '잔존물': '0', '차감소계': '0'}, '합계': {'소계': '1,441,370', '부가세': '10%(144,137)', '합계': '1,585,507', '과실상계': '0%(0)', '면책금': '', '총계': '1,585,507'}, '도장할증': {'보카시': '', '투톤': '', '폴리싱': '', '할증계': '0'}}, '수리내역': [{'No': '1 U', '작업항목 및 부품명': '앞범퍼(스틸형)하단', '작업': '교환', 'HQ%': 1.24, '부품코드': '', '부품가격': '', '공임': '40,920', '비고': ''}, {'No': '2 ', '작업항목 및 부품명': '앞범퍼', '작업': '교환', 'HQ%': 3.01, '부품코드': '', '부품가격': '', '공임': '99,330', '비고': ''}, {'No': '3 ', '작업항목 및 부품명': '헤드램프
# ...

# %%
jsondata

# print(jsondata.split('\t'))
# Out:
# {'차량정보': {'제작사/차종': 'FORD',
#   '차량명칭': '포드',
#   '모델': '기본형',
#   '최초등록일': '20150101',
#   '부품적용일': '20180507',
#   '주행거리': '67,219Km',
#   '입고일자': '20180507',
#   '출고일자': '',
#   '탈부착작업시간': '기존',
#   '탈부착M/H': '33,000원',
#   '판금M/H': '33,000원',
#   '도장작업시간': '기존',
#   '도장M/H': '원',
#   '중복체크': '미완료'},
#  '수리비 정산정보': {'공임': {'탈착교환': '227,370',
#    '판금수리': '363,000',
#    '견인구난': '0',
#    '재료대': '0',
#    '도장공임': '851,000',
#    '할증공임': '0',
#    '가열건조비': '0',
#    '도장정산': '851,000',
#    '공임소계': '1,441,370'},
#   '부품': {'순정부품': '0',
#    '순정정산': '0',
#    '방청부품': '',
#    '방청정산': '',
#    '중고부품': '0',
#    '유리부품': '0',
#    '부품소계': '0',
#    '감가상각': '0',
#    '잔존물': '0',
#    '차감소계': '0'},
#   '합계': {'소계': '1,441,370',
#    '부가세': '10%(144,137)',
#    '합계': '1,585,507',
#    '과실상계': '0%(0)',
#    '면책금': '',
#    '총계': '1,585,507'},
#   '도장할증': {'보카시': '', '투톤': '', '폴리싱': '', '할증계': '0'}},
#  '수리내역': [{'No': '1 U',
#    '작업항목 및 부품명': '앞범퍼(스틸형)하단',
#    '작업': '교환',
# ...

# %%
len(add_list)
# Out:
# 125006

# %%
cars =[]

for i in range(len(add_list)):
    file = open(add_list[i],"r",encoding='utf-8')
    jsondata = json.load(file)
    a = jsondata.get('제작사/차종')
    cars.append(a)

# %%
from collections import Counter

result = Counter(cars).values()
print(result)
# Out:
# dict_values([125006])

# %%
cars =[]

for i in range(len(add_list)):
    file = open(add_list[i],"r",encoding='utf-8')
    jsondata = json.load(file)
    a = jsondata.get('제작사/차종')
    cars.append(a)
    
    print(a)
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ...

# %%
jsondata['차량정보']['차량명칭']
# Out:
# '아반떼AD(16)'

# %%
jsondata
# Out:
# {'차량정보': {'제작사/차종': '현대 / 승용',
#   '차량명칭': '아반떼AD(16)',
#   '모델': '1.6 GDI 스마트',
#   '최초등록일': '20170613',
#   '부품적용일': '20190716',
#   '주행거리': '54595Km',
#   '입고일자': '20190716',
#   '출고일자': '20190716',
#   '탈부착작업시간': '18국토부',
#   '탈부착M/H': '23000원',
#   '판금M/H': '23000원',
#   '도장작업시간': '18국토부 / 유성',
#   '도장M/H': '23000원',
#   '중복체크': '검증완료'},
#  '수리비 정산정보': {'공임': {'탈착교환': '126,730',
#    '판금수리': '23,000',
#    '견인구난': '0',
#    '재료대': '103,300',
#    '도장공임': '99,360',
#    '할증공임': '0',
#    '가열건조비': '15,869',
#    '도장정산': '218,529',
#    '공임소계': '368,259',
#    '청구공임': '368,259'},
#   '부품': {'순정부품': '93,900',
#    '할인률': '0',
#    '순정정산': '93,900',
#    '중고부품': '0',
#    '유리부품': '0',
#    '부품소계': '93,900',
#    '청구부품': '93,900',
#    '감가상각': '0',
#    '잔존물': '0',
#    '차감소계': '0'},
#   '합계': {'합계': '462,159',
#    '부가세': '10(46,216)',
#    '과실상계': '0(0)',
#    '자기부담금': '0',
#    '대차공제': '',
#    '지급액': '508,375',
#    '청구액': '508,375'},
# ...

# %%
jsondata['차량명칭']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 jsondata['차량명칭']
#
# KeyError: '차량명칭'

# %%
cars =[]
maker =[]

for i in range(len(add_list)):
    file = open(add_list[i],"r",encoding='utf-8')
    jsondata = json.load(file)
    a = jsondata['차량정보']['차량명칭']
    made = jsondata['차량정보']['제작사/차종']
    cars.append(a)
    maker.append(made)

# %%
cars
# Out:
# ['포드',
#  'BMW 5시리즈',
#  '씨트로엥',
#  'BMW 520D',
#  'NEW BMW 740Li',
#  '벤츠 A클래스',
#  'BMW 2시리즈',
#  'BMW 5시리즈',
#  '벤츠 G350',
#  '크라이슬러',
#  'BMW 3시리즈',
#  '닛산 인피니티',
#  'BMW 5시리즈',
#  '뉴카니발9인승(06)',
#  '말리부',
#  '혼다',
#  '아반떼AD(16)',
#  '아우디 A6',
#  '포드',
#  '벤츠 E클래스',
#  'K5(18)',
#  '벤츠',
#  '올뉴쏘렌토',
#  'BMW 3시리즈',
#  '말리부',
#  '코란도 C',
#  '아반떼AD(16)',
#  '모하비',
#  '볼보 XC70',
#  '크라이슬러',
#  '그랜져IG(17)',
#  'BMW 쿠퍼',
#  'K3',
#  'K7',
#  '포드',
#  '말리부',
#  'K7',
#  '혼다 어코드',
#  '아우디 A3',
#  '벤츠 C클래스',
#  '도요다 캠리',
#  '벤츠 E300',
#  '폭스바겐 골프',
#  'BMW 3시리즈',
#  '콰트로포르테',
#  '폭스바겐 골프',
#  '혼다 CIVIC',
#  '그랜드 체로키 짚',
#  '폭스바겐 골프',
#  '폭스바겐 파샤트',
#  'BMW 5시리즈',
#  '푸조 508',
#  'BMW 3시리즈',
#  '닛산 인피니티',
#  '닛산 인피니티',
#  '폭스바겐 티구안',
#  '말리부',
#  'BMW X시리즈',
#  'X5',
#  '폭스바겐 골프',
#  'K5(15)',
#  '벤츠 E클래스',
#  '아우디 A6',
#  'K7',
#  'BMW 5시리즈',
#  '크라이슬러',
#  '벤츠 C클래스',
#  '스포티지(16)',
#  'BMW 3시리즈',
#  '벤츠 E클래스',
#  'BMW X시리즈',
#  '벤츠 C클래스',
#  'Range Rover (LP)',
#  'K3',
#  'BMW 5시리즈',
# ...

# %%
maker
# Out:
# ['FORD',
#  'BMW',
#  'CITROEN',
#  'BMW',
#  'BMW',
#  'BENZ',
#  'BMW',
#  'BMW',
#  'BENZ',
#  'CHRYSLER',
#  'BMW',
#  'NISSAN',
#  'BMW',
#  '기아',
#  '한국GM',
#  'HONDA',
#  '현대',
#  'AUDI',
#  'FORD',
#  'BENZ',
#  '기아',
#  'BENZ',
#  '기아',
#  'BMW',
#  '한국GM',
#  '쌍용',
#  '현대',
#  '기아',
#  'VOLVO',
#  'CHRYSLER',
#  '현대',
#  'BMW',
#  '기아',
#  '기아',
#  'FORD',
#  '한국GM',
#  '기아',
#  'HONDA',
#  'AUDI',
#  'BENZ',
#  'TOYOTA',
#  'BENZ',
#  'VOLKSWAGEN',
#  'BMW',
#  'MASERATI',
#  'VOLKSWAGEN',
#  'HONDA',
#  'CHRYSLER',
#  'VOLKSWAGEN',
#  'VOLKSWAGEN',
#  'BMW',
#  'PEUGEOT',
#  'BMW',
#  'NISSAN',
#  'NISSAN',
#  'VOLKSWAGEN',
#  '한국GM',
#  'BMW',
#  'BMW',
#  'VOLKSWAGEN',
#  '기아',
#  'BENZ',
#  'AUDI',
#  '기아',
#  'BMW',
#  'CHRYSLER',
#  'BENZ',
#  '기아',
#  'BMW',
#  'BENZ',
#  'BMW',
#  'BENZ',
#  'LANDROVER',
#  '기아',
#  'BMW',
#  'BENZ',
#  'VOLKSWAGEN',
#  'BMW',
#  '기아',
#  'BMW',
#  'CITROEN',
#  'BENZ',
#  'BENZ',
#  'BENZ',
#  'VOLKSWAGEN',
#  'FORD',
#  'AUDI',
# ...

# %%
from collections import Counter

result = Counter(maker).values()
print(result)
# Out:
# dict_values([115, 638, 13, 517, 110, 84, 20299, 4747, 59, 24943, 234, 2078, 49, 172, 256, 10, 40, 57, 28, 2283, 16, 37, 60, 13, 23, 11, 5, 1, 22, 10, 3, 4, 7, 1, 45, 1, 2, 5, 1, 6, 1, 8138, 27684, 9064, 16745, 2803, 71, 2246, 106, 27, 481, 34, 123, 195, 74, 38, 2, 2, 56, 59, 1, 5, 2, 1, 23, 5, 2, 2, 1, 4, 6])

# %%
len(result)
# Out:
# 71

# %%
m_list = Counter(maker)

type(m_list)
# Out:
# collections.Counter

# %%
sorted(m_list.items())
# Out:
# [('', 37),
#  ('-/-', 106),
#  ('ASTON MARTIN', 6),
#  ('AUDI', 234),
#  ('BAIC(북기은상)', 7),
#  ('BENTLEY', 5),
#  ('BENZ', 517),
#  ('BENZ / 승용', 34),
#  ('BMW', 638),
#  ('BMW / 승용', 195),
#  ('CADILLAC', 23),
#  ('CHRYSLER', 110),
#  ('CHRYSLER / 지프', 2),
#  ('CITROEN', 13),
#  ('Chevrolet', 2),
#  ('DODGE', 1),
#  ('FIAT', 11),
#  ('FORD', 115),
#  ('FORD / 승용', 2),
#  ('GM', 45),
#  ('GMC', 1),
#  ('HONDA', 59),
#  ('INFINITI', 5),
#  ('JAGUAR', 60),
#  ('JEEP', 13),
#  ('JEEP / 승용', 27),
#  ('LANDROVER', 57),
#  ('LEXUS', 16),
#  ('LINCOLN', 4),
#  ('MASERATI', 10),
#  ('MAYBACH', 1),
#  ('MAZDA', 1),
#  ('MINI', 22),
#  ('MINI / 승용', 71),
#  ('MITSUBISHI', 3),
#  ('NISSAN', 84),
#  ('PEUGEOT', 40),
#  ('PORSCHE', 28),
#  ('SUBARU', 1),
#  ('SUZUKI', 10),
#  ('TESLA / 승용', 6),
#  ('TOYOTA', 172),
#  ('VOLKSWAGEN', 256),
#  ('VOLKSWAGEN / 승용', 38),
#  ('VOLVO', 49),
#  ('기아', 20299),
#  ('기아 / RV', 9064),
#  ('기아 / 승용', 16745),
#  ('기아 / 지프', 1),
#  ('랜드로버 / 승용', 5),
# ...

# %%
import pandas as pd
df = pd.DataFrame({"maker":maker,"car":cars})

# %%
df
# Out:
#           maker            car
# 0          FORD             포드
# 1           BMW       BMW 5시리즈
# 2       CITROEN           씨트로엥
# 3           BMW       BMW 520D
# 4           BMW  NEW BMW 740Li
# ...         ...            ...
# 125001  현대 / 승용    아반떼(20)-CN7
# 125002  현대 / 승용    아반떼(20)-CN7
# 125003  기아 / 승용       올뉴모닝(17)
# 125004  기아 / 승용       올뉴모닝(17)
# 125005  기아 / RV            스토닉
#
# [125006 rows x 2 columns]

# %%
maker
# Out:
# ['FORD',
#  'BMW',
#  'CITROEN',
#  'BMW',
#  'BMW',
#  'BENZ',
#  'BMW',
#  'BMW',
#  'BENZ',
#  'CHRYSLER',
#  'BMW',
#  'NISSAN',
#  'BMW',
#  '기아',
#  '한국GM',
#  'HONDA',
#  '현대',
#  'AUDI',
#  'FORD',
#  'BENZ',
#  '기아',
#  'BENZ',
#  '기아',
#  'BMW',
#  '한국GM',
#  '쌍용',
#  '현대',
#  '기아',
#  'VOLVO',
#  'CHRYSLER',
#  '현대',
#  'BMW',
#  '기아',
#  '기아',
#  'FORD',
#  '한국GM',
#  '기아',
#  'HONDA',
#  'AUDI',
#  'BENZ',
#  'TOYOTA',
#  'BENZ',
#  'VOLKSWAGEN',
#  'BMW',
#  'MASERATI',
#  'VOLKSWAGEN',
#  'HONDA',
#  'CHRYSLER',
#  'VOLKSWAGEN',
#  'VOLKSWAGEN',
#  'BMW',
#  'PEUGEOT',
#  'BMW',
#  'NISSAN',
#  'NISSAN',
#  'VOLKSWAGEN',
#  '한국GM',
#  'BMW',
#  'BMW',
#  'VOLKSWAGEN',
#  '기아',
#  'BENZ',
#  'AUDI',
#  '기아',
#  'BMW',
#  'CHRYSLER',
#  'BENZ',
#  '기아',
#  'BMW',
#  'BENZ',
#  'BMW',
#  'BENZ',
#  'LANDROVER',
#  '기아',
#  'BMW',
#  'BENZ',
#  'VOLKSWAGEN',
#  'BMW',
#  '기아',
#  'BMW',
#  'CITROEN',
#  'BENZ',
#  'BENZ',
#  'BENZ',
#  'VOLKSWAGEN',
#  'FORD',
#  'AUDI',
# ...

# %%
df.T
# Out:
#       0         1        2         3              4        5         6       \
# maker   FORD       BMW  CITROEN       BMW            BMW     BENZ       BMW
# car       포드  BMW 5시리즈     씨트로엥  BMW 520D  NEW BMW 740Li  벤츠 A클래스  BMW 2시리즈
#
#          7        8         9       ...       124996     124997     124998  \
# maker       BMW     BENZ  CHRYSLER  ...      현대 / 승용    현대 / 승용    기아 / RV
# car    BMW 5시리즈  벤츠 G350     크라이슬러  ...  아반떼(20)-CN7  아반떼AD(16)  올뉴카니발(14)
#
#         124999       125000       125001       125002    125003    125004  \
# maker  현대 / RV      현대 / 승용      현대 / 승용      현대 / 승용   기아 / 승용   기아 / 승용
# car         코나  아반떼(20)-CN7  아반떼(20)-CN7  아반떼(20)-CN7  올뉴모닝(17)  올뉴모닝(17)
#
#         125005
# maker  기아 / RV
# car        스토닉
#
# [2 rows x 125006 columns]

# %%
df.to_csv('makers.csv')

# %% [markdown]
# # 2트

# %%
add_list = glob('D:\\Down\\car_crushed\\data\\1.Training\\1.원천데이터_230126_add\\TS_99. 붙임_견적서/*.json')

add_list
# Out:
# ['D:\\Down\\car_crushed\\data\\1.Training\\1.원천데이터_230126_add\\TS_99. 붙임_견적서\\as-0000002.json',
#  'D:\\Down\\car_crushed\\data\\1.Training\\1.원천데이터_230126_add\\TS_99. 붙임_견적서\\as-0000004.json',
#  'D:\\Down\\car_crushed\\data\\1.Training\\1.원천데이터_230126_add\\TS_99. 붙임_견적서\\as-0000005.json',
#  'D:\\Down\\car_crushed\\data\\1.Training\\1.원천데이터_230126_add\\TS_99. 붙임_견적서\\as-0000009.json',
#  'D:\\Down\\car_crushed\\data\\1.Training\\1.원천데이터_230126_add\\TS_99. 붙임_견적서\\as-0000011.json',
#  'D:\\Down\\car_crushed\\data\\1.Training\\1.원천데이터_230126_add\\TS_99. 붙임_견적서\\as-0000012.json',
#  'D:\\Down\\car_crushed\\data\\1.Training\\1.원천데이터_230126_add\\TS_99. 붙임_견적서\\as-0000013.json',
#  'D:\\Down\\car_crushed\\data\\1.Training\\1.원천데이터_230126_add\\TS_99. 붙임_견적서\\as-0000018.json',
#  'D:\\Down\\car_crushed\\data\\1.Training\\1.원천데이터_230126_add\\TS_99. 붙임_견적서\\as-0000019.json',
#  'D:\\Down\\car_crushed\\data\\1.Training\\1.원천데이터_230126_add\\TS_99. 붙임_견적서\\as-0000021.json',
# ...

# %%
add_list[0].split('\\')[-1]

add_list[0].split('\\')[-1][:-5] # .json 삭제
# Out:
# 'as-0000002'

# %%
cars = []
maker = []
f_names = []

for i in range(len(add_list)):
    file = open(add_list[i],"r",encoding='utf-8')
    jsondata = json.load(file)
    a = jsondata['차량정보']['차량명칭']
    made = jsondata['차량정보']['제작사/차종']
    cars.append(a)
    maker.append(made)
    f_names.append(add_list[i].split('\\')[-1][:-5])

# %%
len(add_list)/4
# Out:
# 31251.5

# %%
cars = []
maker = []
f_names = []

for i in range(120000, len(add_list)):
    file = open(add_list[i],"r",encoding='utf-8')
    jsondata = json.load(file)
    a = jsondata['차량정보']['차량명칭']
    made = jsondata['차량정보']['제작사/차종']
    cars.append(a)
    maker.append(made)
    f_names.append(add_list[i].split('\\')[-1][:-5])

# %%
cars


maker
f_names
# Out:
# ['as-0000002.json',
#  'as-0000004.json',
#  'as-0000005.json',
#  'as-0000009.json',
#  'as-0000011.json',
#  'as-0000012.json',
#  'as-0000013.json',
#  'as-0000018.json',
#  'as-0000019.json',
#  'as-0000021.json',
#  'as-0000022.json',
#  'as-0000023.json',
#  'as-0000024.json',
#  'as-0000025.json',
#  'as-0000027.json',
#  'as-0000028.json',
#  'as-0000029.json',
#  'as-0000030.json',
#  'as-0000031.json',
#  'as-0000033.json',
#  'as-0000034.json',
#  'as-0000035.json',
#  'as-0000037.json',
#  'as-0000038.json',
#  'as-0000040.json',
#  'as-0000041.json',
#  'as-0000043.json',
#  'as-0000047.json',
#  'as-0000049.json',
#  'as-0000051.json',
#  'as-0000053.json',
#  'as-0000054.json',
#  'as-0000057.json',
#  'as-0000061.json',
#  'as-0000062.json',
#  'as-0000063.json',
#  'as-0000067.json',
#  'as-0000068.json',
#  'as-0000070.json',
#  'as-0000074.json',
#  'as-0000076.json',
#  'as-0000077.json',
#  'as-0000079.json',
#  'as-0000080.json',
#  'as-0000082.json',
# ...

# %%
import pandas as pd
df1 = pd.DataFrame({"maker":maker,"car":cars, 'file_name':f_names})

df1
# Out:
#          maker            car   file_name
# 0         FORD             포드  as-0000002
# 1          BMW       BMW 5시리즈  as-0000004
# 2      CITROEN           씨트로엥  as-0000005
# 3          BMW       BMW 520D  as-0000009
# 4          BMW  NEW BMW 740Li  as-0000011
# ...        ...            ...         ...
# 29995       기아      올뉴카니발(14)  as-0052104
# 29996       기아      올뉴카니발(14)  as-0052105
# 29997       현대      그랜져IG(17)  as-0052106
# 29998       현대      그랜저IG(17)  as-0052111
# 29999       기아         K3(18)  as-0052113
#
# [30000 rows x 3 columns]

# %%
df2 = pd.DataFrame({"maker":maker,"car":cars, 'file_name':f_names})

df2
# Out:
#          maker          car   file_name
# 0           기아     스포티지(16)  as-0052114
# 1           현대    아반떼MD(13)  as-0052116
# 2           기아           쏘울  as-0052117
# 3           기아      셀토스(19)  as-0052119
# 4           현대     GV80(20)  as-0052121
# ...        ...          ...         ...
# 29995  현대 / 승용         아이오닉  sc-1007027
# 29996  기아 / 승용       레이(18)  sc-1007032
# 29997  현대 / 승용  아반떼(20)-CN7  sc-1007034
# 29998  현대 / 승용    아반떼AD(16)  sc-1007036
# 29999  현대 / RV           코나  sc-1007038
#
# [30000 rows x 3 columns]

# %%
df3 = pd.DataFrame({"maker":maker,"car":cars, 'file_name':f_names})

df3
# Out:
#          maker          car   file_name
# 0      현대 / 승용  아반떼(20)-CN7  sc-1007040
# 1      현대 / 승용    아반떼AD(16)  sc-1007041
# 2      기아 / 승용     올뉴모닝(17)  sc-1007042
# 3      기아 / 승용     올뉴모닝(17)  sc-1007043
# 4      현대 / 승용  아반떼(20)-CN7  sc-1007044
# ...        ...          ...         ...
# 29995  기아 / RV    올뉴카니발(14)   sc-154510
# 29996  기아 / 승용       K3(18)   sc-154511
# 29997  기아 / RV    올뉴카니발(14)   sc-154514
# 29998  기아 / RV       올 뉴 쏘울   sc-154516
# 29999  현대 / 승용    아반떼AD(16)   sc-154518
#
# [30000 rows x 3 columns]

# %%
df4 = pd.DataFrame({"maker":maker,"car":cars, 'file_name':f_names})

df4
# Out:
#          maker          car  file_name
# 0      현대 / 승용    아반떼AD(16)  sc-154519
# 1      현대 / 승용    아반떼AD(16)  sc-154520
# 2      현대 / 승용    아반떼AD(16)  sc-154521
# 3      기아 / 승용       레이(18)  sc-154522
# 4      기아 / 승용       K5(15)  sc-154524
# ...        ...          ...        ...
# 29995  기아 / RV          스토닉  sc-220506
# 29996  현대 / RV           코나  sc-220508
# 29997  현대 / 승용    아반떼AD(16)  sc-220509
# 29998  현대 / 승용  아반떼(20)-CN7  sc-220511
# 29999  기아 / 승용       레이(18)  sc-220513
#
# [30000 rows x 3 columns]

# %%
df5 = pd.DataFrame({"maker":maker,"car":cars, 'file_name':f_names})

df5
# Out:
#         maker          car  file_name
# 0     기아 / RV      셀토스(19)  sc-220515
# 1     현대 / RV     올뉴투싼(15)  sc-220519
# 2     현대 / 승용    아반떼AD(16)  sc-220520
# 3     쌍용 / RV          티볼리  sc-220521
# 4     기아 / RV    올뉴카니발(14)  sc-220523
# ...       ...          ...        ...
# 5001  현대 / 승용  아반떼(20)-CN7  sc-230535
# 5002  현대 / 승용  아반떼(20)-CN7  sc-230537
# 5003  기아 / 승용     올뉴모닝(17)  sc-230540
# 5004  기아 / 승용     올뉴모닝(17)  sc-230555
# 5005  기아 / RV          스토닉  sc-230558
#
# [5006 rows x 3 columns]

# %%
df1.to_csv('add_1.csv', index=False) # 0~29999 range(30000)

# %%
df2.to_csv('add_2.csv', index=False) # 0~29999 range(30000, 600000)

# %%
df3.to_csv('add_3.csv', index=False) # 0~29999 range(60000, 900000)

# %%
df4.to_csv('add_4.csv', index=False) # 0~29999 range(90000, 1200000)

# %%
df5.to_csv('add_5.csv', index=False) # 0~5006 range(120000, len(add_list))

# %%
df1 = pd.read_csv('add_1.csv', encoding="utf-8")
df2 = pd.re
# Out:
#          maker            car   file_name
# 0         FORD             포드  as-0000002
# 1          BMW       BMW 5시리즈  as-0000004
# 2      CITROEN           씨트로엥  as-0000005
# 3          BMW       BMW 520D  as-0000009
# 4          BMW  NEW BMW 740Li  as-0000011
# ...        ...            ...         ...
# 29995       기아      올뉴카니발(14)  as-0052104
# 29996       기아      올뉴카니발(14)  as-0052105
# 29997       현대      그랜져IG(17)  as-0052106
# 29998       현대      그랜저IG(17)  as-0052111
# 29999       기아         K3(18)  as-0052113
#
# [30000 rows x 3 columns]

# %%
df1['maker'].unique()
# Out:
# array(['FORD', 'BMW', 'CITROEN', 'BENZ', 'CHRYSLER', 'NISSAN', '기아',
#        '한국GM', 'HONDA', '현대', 'AUDI', '쌍용', 'VOLVO', 'TOYOTA',
#        'VOLKSWAGEN', 'MASERATI', 'PEUGEOT', 'LANDROVER', 'PORSCHE',
#        '르노삼성', 'LEXUS', nan, 'JAGUAR', 'JEEP', 'CADILLAC', 'FIAT',
#        'BENTLEY', 'DODGE', 'MINI', 'SUZUKI', 'MITSUBISHI', 'LINCOLN',
#        'BAIC(북기은상)', 'SUBARU', 'GM'], dtype=object)

# %%
data_list = glob("D:\\Down\\car\\data\\Training\\feature\\TS_damage\\damage/*.jpg")

# %%
a = []

data_list[0].split("_")[-1].split(".")[0]
# Out:
# 'as-0036229'

# %%
df1[df1['maker'] == "기아"]['file_name']
# Out:
# 13       as-0000025
# 20       as-0000034
# 22       as-0000037
# 27       as-0000047
# 32       as-0000057
#             ...
# 29993    as-0052102
# 29994    as-0052103
# 29995    as-0052104
# 29996    as-0052105
# 29999    as-0052113
# Name: file_name, Length: 11515, dtype: object

# %%
maker_list = ['한국GM', '현대', '쌍용','기아', '르노삼성', '현대 / 승용', '기아 / 승용', '기아 / RV', '현대 / RV',
             '한국GM / 승용', '쌍용 / RV', '르노삼성 / 승용', '한국GM / RV', '르노삼성 / RV','기아 / 지프',

# %%
df1[df1['maker'].isin(maker_list)]['file_name']
# Out:
# 13       as-0000025
# 14       as-0000027
# 16       as-0000029
# 20       as-0000034
# 22       as-0000037
#             ...
# 29995    as-0052104
# 29996    as-0052105
# 29997    as-0052106
# 29998    as-0052111
# 29999    as-0052113
# Name: file_name, Length: 29154, dtype: object

# %%
30000 - 29154
# Out:
# 846

# %%
df_list = []

for i in range(1, 6):
    df = pd.read_csv(f"add_{i}.csv")
    df_list.append(df)

# %%
df_list[0]
# Out:
#          maker            car   file_name
# 0         FORD             포드  as-0000002
# 1          BMW       BMW 5시리즈  as-0000004
# 2      CITROEN           씨트로엥  as-0000005
# 3          BMW       BMW 520D  as-0000009
# 4          BMW  NEW BMW 740Li  as-0000011
# ...        ...            ...         ...
# 29995       기아      올뉴카니발(14)  as-0052104
# 29996       기아      올뉴카니발(14)  as-0052105
# 29997       현대      그랜져IG(17)  as-0052106
# 29998       현대      그랜저IG(17)  as-0052111
# 29999       기아         K3(18)  as-0052113
#
# [30000 rows x 3 columns]

# %%
json_list=[]

for df in df_list:
    a = df[df['maker'].isin(maker_list)]['file_name']
    json_list.append(a)

# %%
json_list
# Out:
# [13       as-0000025
#  14       as-0000027
#  16       as-0000029
#  20       as-0000034
#  22       as-0000037
#              ...
#  29995    as-0052104
#  29996    as-0052105
#  29997    as-0052106
#  29998    as-0052111
#  29999    as-0052113
#  Name: file_name, Length: 29154, dtype: object,
#  0        as-0052114
#  1        as-0052116
#  2        as-0052117
#  3        as-0052119
#  4        as-0052121
#              ...
#  26999    as-0100161
#  27000    as-0100166
#  27001    as-0100168
#  27002    as-0100171
#  27003    as-0100172
#  Name: file_name, Length: 25196, dtype: object,
#  Series([], Name: file_name, dtype: object),
#  Series([], Name: file_name, dtype: object),
#  Series([], Name: file_name, dtype: object)]

# %%
df_list[1]['maker'].unique()
# Out:
# array(['기아', '현대', '한국GM', '르노삼성', 'JAGUAR', '쌍용', 'BMW', 'NISSAN',
#        'FORD', 'PORSCHE', 'CADILLAC', 'VOLKSWAGEN', 'AUDI', 'GM',
#        'SUZUKI', 'BENZ', 'LANDROVER', 'HONDA', 'MINI', 'TOYOTA',
#        'CHRYSLER', 'CITROEN', 'JEEP', 'FIAT', 'VOLVO', 'PEUGEOT',
#        'BENTLEY', 'MASERATI', 'LEXUS', 'MAYBACH', 'Chevrolet', 'INFINITI',
#        'GMC', 'LINCOLN', 'BAIC(북기은상)', 'ASTON MARTIN', nan, 'MAZDA',
#        '현대 / RV', '현대 / 승용', '기아 / RV', '기아 / 승용', '쌍용 / RV', 'MINI / 승용',
#        '한국GM / 승용', '-/-', 'JEEP / 승용', '르노삼성 / 승용', 'BENZ / 승용',
#        '한국GM / RV', 'BMW / 승용', '르노삼성 / RV'], dtype=object)

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 df_list[5]['maker'].unique()
#
# IndexError: list index out of range

# %%
maker_list = ['한국GM', '현대', '쌍용','기아', '르노삼성', '현대 / 승용', '기아 / 승용', '기아 / RV', '현대 / RV',
             '한국GM / 승용', '쌍용 / RV', '르노삼성 / 승용', '한국GM / RV', '르노삼성 / RV','기아 / 지프']

# %%
from collections import Counter

# %%
Counter(maker_list)
# Out:
# Counter({'한국GM': 1,
#          '현대': 1,
#          '쌍용': 1,
#          '기아': 1,
#          '르노삼성': 1,
#          '현대 / 승용': 1,
#          '기아 / 승용': 1,
#          '기아 / RV': 1,
#          '현대 / RV': 1,
#          '한국GM / 승용': 1,
#          '쌍용 / RV': 1,
#          '르노삼성 / 승용': 1,
#          '한국GM / RV': 1,
#          '르노삼성 / RV': 1,
#          '기아 / 지프': 1})

# %%
json_list=[]

for df in df_list:
    a = df[df['maker'].isin(maker_list)]['file_name']
    json_list.append(a)

# %%
b=0
for i in range(len(json_list)):
    b = b +(len(json_list[i]))
    
print(b)
# Out:
# 121709

# %%
json_list[0]
# Out:
# 13       as-0000025
# 14       as-0000027
# 16       as-0000029
# 20       as-0000034
# 22       as-0000037
#             ...
# 29995    as-0052104
# 29996    as-0052105
# 29997    as-0052106
# 29998    as-0052111
# 29999    as-0052113
# Name: file_name, Length: 29154, dtype: object

# %%
for i in json_list:
    i.reset_index(drop= True, inplace=True)

# %%
df_1st = pd.DataFrame({'file_name':json_list[0]})
df_2nd = pd.DataFrame({'file_name':json_list[1]})
df_3rd = pd.DataFrame({'file_name':json_list[2]})
df_4th = pd.DataFrame({'file_name':json_list[3]})
df_5th = pd.DataFrame({'file_name':json_list[4]})

# %%
final = pd.concat([df_1st, df_2nd, df_3rd, df_4th, df_5th], axis=0)

# %%
final.reset_index(drop=True, inplace=True)

# %%
final
# Out:
#          file_name
# 0       as-0000025
# 1       as-0000027
# 2       as-0000029
# 3       as-0000034
# 4       as-0000037
# ...            ...
# 121704   sc-230535
# 121705   sc-230537
# 121706   sc-230540
# 121707   sc-230555
# 121708   sc-230558
#
# [121709 rows x 1 columns]

# %%
final.iloc[:,0]
# Out:
# 0         as-0000025
# 1         as-0000027
# 2         as-0000029
# 3         as-0000034
# 4         as-0000037
#              ...
# 121704     sc-230535
# 121705     sc-230537
# 121706     sc-230540
# 121707     sc-230555
# 121708     sc-230558
# Name: file_name, Length: 121709, dtype: object

# %%
125006-121709
# Out:
# 3297

# %%
final.to_csv('kor_car.csv',index=False)
