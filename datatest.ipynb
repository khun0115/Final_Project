# %%
import os

os.getcwd()
# Out:
# '/Users/kimdohyun/Downloads/final_project'

# %%
from glob import glob

j_list = glob('/Users/kimdohyun/Downloads/final_project/New_Sample/라벨링데이터/TL_damage/damage/*.json')
j_list[0]
# Out:
# '/Users/kimdohyun/Downloads/final_project/New_Sample/라벨링데이터/TL_damage/damage/0063158_sc-155544.json'

# %%
import json

file = open(j_list[0],"r",encoding='utf-8')
jsondata = json.load(file)

print(type(jsondata))
print(jsondata)
# Out:
# <class 'dict'>
# {'info': {'name': 'socar', 'date_created': '03/08/2022'}, 'images': {'id': 1, 'width': 960, 'height': 720, 'file_name': '0063158_sc-155544.jpg'}, 'annotations': [{'id': 2, 'image_id': 1, 'category_id': 'sc-155544', 'segmentation': [[[[543, 312], [715, 282], [773, 291], [713, 329], [549, 340], [543, 312]]]], 'area': 7713.0, 'bbox': [543, 282, 230, 58], 'damage': 'Breakage', 'part': None, 'year': 2018, 'color': 'White', 'level': None, 'repair': []}, {'id': 3, 'image_id': 1, 'category_id': 'sc-155544', 'segmentation': [[[[448, 160], [496, 251], [552, 360], [576, 491], [578, 584], [560, 692], [550, 694], [566, 590], [564, 517], [543, 398], [526, 338], [469, 213], [440, 162], [448, 160]]]], 'area': 6706.5, 'bbox': [440, 160, 138, 534], 'damage': 'Scratched', 'part': None, 'year': 2018, 'color': 'White', 'level': None, 'repair': []}], 'categories': {'id': 'sc-155544', 'supercategory_name': 'Compact car'}}

# %%
print(json.dumps(jsondata,indent='\t'))
# Out:
# {
# 	"info": {
# 		"name": "socar",
# 		"date_created": "03/08/2022"
# 	},
# 	"images": {
# 		"id": 1,
# 		"width": 960,
# 		"height": 720,
# 		"file_name": "0063158_sc-155544.jpg"
# 	},
# 	"annotations": [
# 		{
# 			"id": 2,
# 			"image_id": 1,
# 			"category_id": "sc-155544",
# 			"segmentation": [
# 				[
# 					[
# 						[
# 							543,
# 							312
# 						],
# 						[
# 							715,
# 							282
# 						],
# 						[
# 							773,
# 							291
# 						],
# 						[
# 							713,
# 							329
# 						],
# 						[
# 							549,
# 							340
# 						],
# 						[
# 							543,
# 							312
# 						]
# 					]
# 				]
# 			],
# 			"area": 7713.0,
# 			"bbox": [
# 				543,
# 				282,
# 				230,
# 				58
# 			],
# 			"damage": "Breakage",
# 			"part": null,
# 			"year": 2018,
# 			"color": "White",
# 			"level": null,
# 			"repair": []
# 		},
# 		{
# 			"id": 3,
# 			"image_id": 1,
# 			"category_id": "sc-155544",
# 			"segmentation": [
# 				[
# 					[
# 						[
# 							448,
# ...

# %%
file = open(j_list[1],"r",encoding='utf-8')
jsondata = json.load(file)

# print(type(jsondata))
print(jsondata)

print(json.dumps(jsondata,indent='\t'))
# Out:
# {'info': {'name': 'external', 'date_created': '03/08/2022'}, 'images': {'id': 1, 'width': 800, 'height': 1067, 'file_name': '0349939_as-2753180.jpg'}, 'annotations': [{'id': 2, 'image_id': 1, 'category_id': 'as-2753180', 'segmentation': [[[[0, 476], [490, 414], [409, 431], [0, 495], [0, 476]]]], 'area': 5539.5, 'bbox': [0, 414, 490, 81], 'damage': 'Separated', 'part': None, 'year': 2016, 'color': 'Red tone', 'level': None, 'repair': ['Front bumper:coating,exchange', 'Front Wheel(R):exchange', 'Head lights:exchange', 'Front fender(R):coating,exchange']}, {'id': 3, 'image_id': 1, 'category_id': 'as-2753180', 'segmentation': [[[[0, 492], [306, 443], [535, 410], [586, 447], [639, 466], [733, 466], [793, 477], [799, 476], [797, 667], [742, 649], [641, 663], [487, 701], [428, 722], [299, 683], [247, 630], [147, 684], [69, 745], [3, 810], [0, 492]]]], 'area': 188330.5, 'bbox': [0, 410, 799, 400], 'damage': 'Crushed', 'part': None, 'year': 2016, 'color': 'Red tone', 'level': None, 'repair': 
# ...

# %%
file = open(j_list[2],"r",encoding='utf-8')
jsondata = json.load(file)


print(json.dumps(jsondata,indent='\t'))
# Out:
# {
# 	"info": {
# 		"name": "socar",
# 		"date_created": "03/08/2022"
# 	},
# 	"images": {
# 		"id": 1,
# 		"width": 1280,
# 		"height": 960,
# 		"file_name": "0327762_sc-198391.jpg"
# 	},
# 	"annotations": [
# 		{
# 			"id": 2,
# 			"image_id": 1,
# 			"category_id": "sc-198391",
# 			"segmentation": [
# 				[
# 					[
# 						[
# 							798,
# 							409
# 						],
# 						[
# 							792,
# 							424
# 						],
# 						[
# 							774,
# 							473
# 						],
# 						[
# 							754,
# 							512
# 						],
# 						[
# 							737,
# 							573
# 						],
# 						[
# 							716,
# 							672
# 						],
# 						[
# 							685,
# 							723
# 						],
# 						[
# 							634,
# 							750
# 						],
# 						[
# 							623,
# 							742
# 						],
# 						[
# 							620,
# 							716
# 						],
# 						[
# 							630,
# 							656
# 						],
# 						[
# 							641,
# 							562
# 						],
# 						[
# 							663,
# 							520
# 						],
# 						[
# 							719,
# 							472
# 						],
# ...

# %% [markdown]
# id:1 은 이미지. 2부터 파손 종류의 정보 담은 주석. category 에도 id 1개 있으므로 findall(len(id))-2 하면 파손 종류 개수?
#
# segmentation 좌표로 면적 그려서 파손별 영역 파악?
